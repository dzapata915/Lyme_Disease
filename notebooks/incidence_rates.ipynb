# 8       40     121     103      84      79     100     120      91      77
# 9      155     166     216     210     169     162     121     193     233
# 10       4       8       4       8      19      18      32      35      31
# 11       9       9      17      20       9      14       6       6      10
# 12     233     287     237     273     276     395     295     540     259
# 13     110     138     152     142     155     189     212     314     236
# 14     194     318     232     255     283     303     257     359     154
# 15      20      23      39      40      30      35      17      22       9
# 16      44      49      33      20      22      22      32      41      72
# 17       2       3       7      12       4       8       2       4       5
# 18   1,401   1,201   1,487   1,850   1,405   2,167   1,128   1,510    2653
# 19   1,373   1,728   1,866   1,891   1,382   1,417     842     916    2035
# 20   5,304   4,224     198     410      16       7     107      27    5052
# 21     127     148     221     291     262     413     468     862     557
# 22   1,416   1,805   2,126   2,318   1,541   1,528       0   1,902    2685
# 23       2       4       1       1       4       4       1       1       3
# 24      10       5      10      12      11      17       7       7       7
# 25       7       5      17      12       7       8       3      13      13
# 26       7      11      14      14      15      10       5      10       9
# 27       6       7      15      17      14      17       4      17      10
# 28     724     529     891   1,381   1,428   1,710     299     397    1085
# 29   3,286   4,855   4,350   5,092   4,000   3,619   2,566   3,518    5897
# 30       0       0       1       3       2       7       0       2       3
# 31   3,736   4,314   3,882   5,155   3,638   4,243   2,240   3,006   16798
# 32     170     230     272     295     212     334     264     338     279
# 33      14      33      32      56      33      38      36      34      22
# 34     119     154     160     270     293     467     409     590     553
# 35       0       0       0       1       0       0       0       0       0
# 36      45      31      61      84      70      65      39      74      61
# 37   7,487   9,048  11,443  11,900  10,208   8,998   3,334   2,900    8413
# 38     904     904     903   1,132   1,111     971     839     980    2326
# 39      37      42      51      21      39      47      48      76      44
# 40       2       5      11      12       7      10       8      16      12
# 41      17      26      25      47      29      45      38      57      32
# 42      40      54      71      58      47      41      11      32      23
# 43      13       7      19      25      27      19      14      18      16
# 44     599     710     761   1,092     576   1,064      59     115    1312
# 45   1,346   1,539   1,350   1,657   1,139   1,199     555     705    1403
# 46      15      24      31      37      20      43      20      43      23
# 47     136     289     368     648     671     885   1,065   1,792    2470
# 48   1,361   1,894   2,295   3,000   1,869   2,178   1,447   2,193    5208
# 49       3       1       1       4       0       5       0       2       4
# 50  33,461  38,069  36,429  42,743  33,666  34,945  18,000  24,610  62,519
#
#       2023
# 0       36
# 1        2
# 2       16
# 3        5
# 4      109
# 5       32
# 6    3,239
# 7      349
# 8      108
# 9      271
# 10      18
# 11      11
# 12     372
# 13     257
# 14     212
# 15      12
# 16     120
# 17      15
# 18   2,942
# 19   2,470
# 20   9,715
# 21   1,152
# 22   2,938
# 23       4
# 24      16
# 25      11
# 26       5
# 27      14
# 28   1,573
# 29   7,224
# 30      11
# 31  22,173
# 32     228
# 33      15
# 34   1,307
# 35       3
# 36      61
# 37  16,671
# 38   2,852
# 39      55
# 40       7
# 41      50
# 42      27
# 43      16
# 44   1,445
# 45   1,747
# 46      25
# 47   3,242
# 48   6,283
# 49       2
# 50  89,468

# %%
statecount_2023=count_by_state[['State','2023']]

# %%
statecount_2023['2023'] = pd.to_numeric(statecount_2023['2023'].str.replace(',', '', regex=False), errors='coerce')
# Out:
# C:\Users\dzapa\AppData\Local\Temp\ipykernel_40948\3684411816.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   statecount_2023['2023'] = pd.to_numeric(statecount_2023['2023'].str.replace(',', '', regex=False), errors='coerce')

# %%
statecount_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   State   51 non-null     object
#  1   2023    51 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 948.0+ bytes

# %%
statecount_2023.head()
# Out:
#         State  2023
# 0     Alabama    36
# 1      Alaska     2
# 2     Arizona    16
# 3    Arkansas     5
# 4  California   109

# %%
state_pops=pd.read_csv('../../data/Census Population by State 2020-2024.csv')

# %%
state_pops
# Out:
#           Geographic Area April 1, 2020 Estimates Base  \
# 0                     NaN                          NaN
# 1           United States                  331,515,736
# 2               Northeast                   57,617,706
# 3                 Midwest                   68,998,970
# 4                   South                  126,281,537
# 5                    West                   78,617,523
# 6                .Alabama                    5,025,369
# 7                 .Alaska                      733,395
# 8                .Arizona                    7,158,110
# 9               .Arkansas                    3,011,553
# 10            .California                   39,555,674
# 11              .Colorado                    5,775,324
# 12           .Connecticut                    3,607,701
# 13              .Delaware                      989,955
# 14  .District of Columbia                      689,545
# 15               .Florida                   21,538,192
# 16               .Georgia                   10,713,755
# 17                .Hawaii                    1,455,252
# 18                 .Idaho                    1,839,140
# 19              .Illinois                   12,821,814
# 20               .Indiana                    6,786,587
# 21                  .Iowa                    3,190,546
# 22                .Kansas                    2,937,745
# 23              .Kentucky                    4,506,302
# 24             .Louisiana                    4,657,874
# 25                 .Maine                    1,363,196
# 26              .Maryland                    6,181,629
# 27         .Massachusetts                    7,033,132
# 28              .Michigan                   10,079,338
# 29             .Minnesota                    5,706,692
# 30           .Mississippi                    2,961,278
# 31              .Missouri                    6,154,854
# 32               .Montana                    1,084,216
# 33              .Nebraska                    1,961,996
# 34                .Nevada                    3,105,595
# 35         .New Hampshire                    1,377,546
# 36            .New Jersey                    9,289,014
# 37            .New Mexico                    2,117,555
# 38              .New York                   20,203,772
# 39        .North Carolina                   10,441,499
# 40          .North Dakota                      779,046
# 41                  .Ohio                   11,799,453
# 42              .Oklahoma                    3,959,405
# 43                .Oregon                    4,237,224
# 44          .Pennsylvania                   13,002,909
# 45          .Rhode Island                    1,097,354
# 46        .South Carolina                    5,118,252
# 47          .South Dakota                      886,729
# 48             .Tennessee                    6,912,347
# 49                 .Texas                   29,149,458
# 50                  .Utah                    3,271,608
# 51               .Vermont                      643,082
# 52              .Virginia                    8,631,388
# 53            .Washington                    7,707,586
# 54         .West Virginia                    1,793,736
# 55             .Wisconsin                    5,894,170
# 56               .Wyoming                      576,844
#
#    Population Estimate (as of July 1)   Unnamed: 3   Unnamed: 4   Unnamed: 5  \
# 0                                2020         2021         2022         2023
# 1                         331,577,720  332,099,760  334,017,321  336,806,231
# 2                          57,431,458   57,252,533   57,159,597   57,398,303
# 3                          68,984,258   68,872,831   68,903,297   69,186,401
# 4                         126,476,549  127,368,010  129,037,849  130,893,358
# 5                          78,685,455   78,606,386   78,916,578   79,328,169
# 6                           5,033,094    5,049,196    5,076,181    5,117,673
# 41          NaN          NaN          NaN          NaN
# 42          NaN          NaN          NaN          NaN
# 43          NaN          NaN          NaN          NaN
# 44          NaN          NaN          NaN          NaN
# 45          NaN          NaN          NaN          NaN
# 46          NaN          NaN          NaN          NaN
# 47          NaN          NaN          NaN          NaN
# 48          NaN          NaN          NaN          NaN
# 49          NaN          NaN          NaN          NaN
# 50          NaN          NaN          NaN          NaN
# 51          NaN          NaN          NaN          NaN
# 52          NaN          NaN          NaN          NaN
# 53          NaN          NaN          NaN          NaN
# 54          NaN          NaN          NaN          NaN
# 55          NaN          NaN          NaN          NaN
# 56          NaN          NaN          NaN          NaN
#
# [57 rows x 36 columns]

# %%
state_pops.columns
# Out:
# Index(['Geographic Area', 'April 1, 2020 Estimates Base',
#        'Population Estimate (as of July 1)', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35'],
#       dtype='object')

# %%
state_pops=state_pops[['Geographic Area',
       'Population Estimate (as of July 1)', 'Unnamed: 3', 'Unnamed: 4',
       'Unnamed: 5', 'Unnamed: 6']]

# %%
state_pops=state_pops.drop(index=[2,3,4,5])

# %%
state_pops.columns=['Geographic Area','Pop_2020','Pop_2021','Pop_2022','Pop_2023','Pop_2024']

# %%
state_pops=state_pops.drop(index=0)

# %%
state_pops['Geographic Area']=state_pops['Geographic Area'].str.replace('.','',regex=False)

# %%
pops_2023= state_pops[['Geographic Area','Pop_2023']]

# %%
pops_2023.head()
# Out:
#   Geographic Area     Pop_2023
# 1   United States  336,806,231
# 6         Alabama    5,117,673
# 7          Alaska      736,510
# 8         Arizona    7,473,027
# 9        Arkansas    3,069,463

# %%
statecount_2023.head()
# Out:
#         State  2023
# 0     Alabama    36
# 1      Alaska     2
# 2     Arizona    16
# 3    Arkansas     5
# 4  California   109

# %%
state_incidence= pd.merge(statecount_2023,pops_2023, left_on='State',right_on='Geographic Area')

# %%
state_incidence=state_incidence.drop(columns='Geographic Area')

# %%
state_incidence.columns=['State','Lyme_Case_Count_2023','Pop_2023']

# %%
state_incidence.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   State                 50 non-null     object
#  1   Lyme_Case_Count_2023  50 non-null     int64
#  2   Pop_2023              50 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 1.3+ KB

# %%
state_incidence['Pop_2023']=state_incidence['Pop_2023'].str.replace(',', '').astype(int)

# %%
state_incidence.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   State                 50 non-null     object
#  1   Lyme_Case_Count_2023  50 non-null     int64
#  2   Pop_2023              50 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.3+ KB

# %%
state_incidence['incidence_rate_per_100k']=round((state_incidence['Lyme_Case_Count_2023']/state_incidence['Pop_2023'])*100000,1)

# %%
state_incidence.sort_values('incidence_rate_per_100k',ascending=False).head(10)
# Out:
#             State  Lyme_Case_Count_2023  Pop_2023  incidence_rate_per_100k
# 38   Rhode Island                  2852   1103429                    258.5
# 44        Vermont                  1445    648708                    222.8
# 18          Maine                  2942   1399646                    210.2
# 47  West Virginia                  3242   1770495                    183.1
# 20  Massachusetts                  9715   7066568                    137.5
# 37   Pennsylvania                 16671  13017721                    128.1
# 31       New York                 22173  19737367                    112.3
# 28  New Hampshire                  1573   1402199                    112.2
# 48      Wisconsin                  6283   5930405                    105.9
# 6     Connecticut                  3239   3643023                     88.9

# %%
state_incidence_sorted = state_incidence.sort_values(
    by='incidence_rate_per_100k',
    ascending=False
).head(10)


state_incidence_sorted = state_incidence_sorted.sort_values(
    by='incidence_rate_per_100k',
    ascending=False
)

plt.figure(figsize=(10, 6))
sns.barplot(
    data=state_incidence_sorted,
    y='State',
    x='incidence_rate_per_100k',
    palette='YlGn_r'  
)

plt.title('Incidence Rate 2023', fontsize=16)
plt.xlabel('Incidence Rate per 100,000', fontsize=14)
plt.ylabel('', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\dzapa\AppData\Local\Temp\ipykernel_40948\1629788137.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
US_pops = state_pops.loc[state_pops['Geographic Area']=='United States']

# %%
US_pops_2023= US_pops[['Geographic Area','Pop_2023']]

# %%
US_pops_2023
# Out:
#   Geographic Area     Pop_2023
# 1   United States  336,806,231

# %%
US_pops_2023['Pop_2023'] = US_pops_2023['Pop_2023'].str.replace(',', '', regex=False).astype(int)
# Out:
# C:\Users\dzapa\AppData\Local\Temp\ipykernel_40948\3272224931.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   US_pops_2023['Pop_2023'] = US_pops_2023['Pop_2023'].str.replace(',', '', regex=False).astype(int)

# %%
US_pops_2023
# Out:
#   Geographic Area   Pop_2023
# 1   United States  336806231

# %%
US_case_count=pd.read_csv('../../data/Overall US Case Count by Year 1996-2023.csv')

# %%
US_cases_2023=US_case_count.loc[US_case_count['Year']==2023]
US_cases_2023
# Out:
#     Year  Cases
# 27  2023  89468

# %%
us_pop = US_pops_2023.loc[US_pops_2023['Geographic Area'] == 'United States', 'Pop_2023'].values[0]
us_cases = US_cases_2023.loc[US_cases_2023['Year'] == 2023, 'Cases'].values[0]

# %%
us_summary_2023 = pd.DataFrame({
    'Year': [2023],
    'US_Population': [us_pop],
    'Total_Cases': [us_cases]
})

# %%
us_summary_2023
# Out:
#    Year  US_Population  Total_Cases
# 0  2023      336806231        89468

# %%
us_summary_2023['Incidence_per_100k'] = round((us_summary_2023['Total_Cases'] / us_summary_2023['US_Population']) * 100000,1)

# %%
us_summary_2023
# Out:
#    Year  US_Population  Total_Cases  Incidence_per_100k
# 0  2023      336806231        89468                26.6

# %%
total_cases_US =pd.read_csv('../../data/Total US LD cases 2023.csv')

# %%
total_cases_US
# Out:
#                    Report Method  Year  US_Population  Total_Cases  \
# 0  Routine National Surveillance  2023      336806231        89468
# 1                  Other Methods  2023      336806231       476000
#
#    Incidence_per_100k
# 0                  27
# 1                 141

# %%
plt.figure(figsize=(8, 6))
barplot = sns.barplot(
    data=total_cases_US,
    x='Report Method',
    y='Total_Cases',
    palette='YlGn_r'
)


for container in barplot.containers:
    barplot.bar_label(
        container,
        labels=[f'{int(v.get_height()):,}' for v in container],
        label_type='edge',
        padding=3,
        color='#333333',
        fontsize=10
    )

plt.title('Lyme Disease Case Counts by Report Method (2023)', fontsize=14)
plt.ylabel('Total Cases')
plt.xlabel('Report Method')
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\dzapa\AppData\Local\Temp\ipykernel_40948\2463093088.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(

# %%
plt.figure(figsize=(8, 6))
barplot = sns.barplot(
    data=total_cases_US,
    x='Report Method',
    y='Incidence_per_100k',
    palette='YlGn_r'
)


for container in barplot.containers:
    barplot.bar_label(
        container,
        labels=[f'{v.get_height():,.0f}' for v in container],  
        label_type='edge',
        padding=3,
        color='#333333',
        fontsize=10
    )

plt.title('Lyme Disease Incidence Rate by Report Method (per 100k)', fontsize=14)
plt.ylabel('Incidence Rate per 100k')
plt.xlabel('Report Method')
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\dzapa\AppData\Local\Temp\ipykernel_40948\4145705754.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(

# %%
state_incidence.loc[state_incidence['State']=='Tennessee']
# Out:
#         State  Lyme_Case_Count_2023  Pop_2023  incidence_rate_per_100k
# 41  Tennessee                    50   7148304                      0.7

# %%
county_cases = pd.read_csv('../../data/Cleaned Data Python/Cleaned County Cases 2001-2023.csv')

# %%
Tennessee_counts = county_cases.loc[county_cases['State']=='Tennessee']

# %%
TN_23_casecounts = Tennessee_counts[['County','State','2023']]

# %%
TN_23_casecounts.columns=['County','State','Case_count_2023']
TN_23_casecounts
# Out:
#                  County      State  Case_count_2023
# 2428    Anderson County  Tennessee                0
# 2429     Bedford County  Tennessee                0
# 2430      Benton County  Tennessee                0
# 2431     Bledsoe County  Tennessee                0
# 2432      Blount County  Tennessee                0
# ...                 ...        ...              ...
# 2518       Wayne County  Tennessee                0
# 2519     Weakley County  Tennessee                0
# 2520       White County  Tennessee                0
# 2521  Williamson County  Tennessee                3
# 2522      Wilson County  Tennessee                0
#
# [95 rows x 3 columns]

# %%
TN_pop = pd.read_csv('../../data/Census Population by TN County 2020-2024.csv')

# %%
TN_pop[95:]
# Out:
#                                        Geographic Area  \
# 95                       .Williamson County, Tennessee
# 96                           .Wilson County, Tennessee
# 97   The Census Bureau has reviewed this data produ...
# 98   Note: The estimates are developed from a base ...
# 99                                 Suggested Citation:
# 100  Annual Estimates of the Resident Population fo...
# 101    Source: U.S. Census Bureau, Population Division
# 102                           Release Date: March 2025
#
#     April 1, 2020 Estimates Base Population Estimate (as of July 1)  \
# 95                       247,777                            249,616
# 96                       147,739                            148,651
# 97                           NaN                                NaN
# 98                           NaN                                NaN
# 99                           NaN                                NaN
# 100                          NaN                                NaN
# 101                          NaN                                NaN
# 102                          NaN                                NaN
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 95     256,155    261,536    265,312    269,136         NaN         NaN
# 96     152,044    159,029    164,352    169,948         NaN         NaN
# 97         NaN        NaN        NaN        NaN         NaN         NaN
# 98         NaN        NaN        NaN        NaN         NaN         NaN
# 99         NaN        NaN        NaN        NaN         NaN         NaN
# 100        NaN        NaN        NaN        NaN         NaN         NaN
# 101        NaN        NaN        NaN        NaN         NaN         NaN
# 102        NaN        NaN        NaN        NaN         NaN         NaN
#
#      Unnamed: 9  ...  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 95          NaN  ...          NaN          NaN          NaN          NaN
# 96          NaN  ...          NaN          NaN          NaN          NaN
# 97          NaN  ...          NaN          NaN          NaN          NaN
# 98          NaN  ...          NaN          NaN          NaN          NaN
# 99          NaN  ...          NaN          NaN          NaN          NaN
# 100         NaN  ...          NaN          NaN          NaN          NaN
# 101         NaN  ...          NaN          NaN          NaN          NaN
# 102         NaN  ...          NaN          NaN          NaN          NaN
#
#      Unnamed: 24  Unnamed: 25  Unnamed: 26  Unnamed: 27  Unnamed: 28  \
# 95           NaN          NaN          NaN          NaN          NaN
# 96           NaN          NaN          NaN          NaN          NaN
# 97           NaN          NaN          NaN          NaN          NaN
# 98           NaN          NaN          NaN          NaN          NaN
# 99           NaN          NaN          NaN          NaN          NaN
# 100          NaN          NaN          NaN          NaN          NaN
# 101          NaN          NaN          NaN          NaN          NaN
# 102          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 29
# 95           NaN
# 96           NaN
# 97           NaN
# 98           NaN
# 99           NaN
# 100          NaN
# 101          NaN
# 102          NaN
#
# [8 rows x 30 columns]

# %%
TN_pop = TN_pop.drop(TN_pop.index[97:])

# %%
TN_pop.head(3)
# Out:
#                Geographic Area April 1, 2020 Estimates Base  \
# 0                          NaN                          NaN
# 1                    Tennessee                    6,912,347
# 2  .Anderson County, Tennessee                       77,154
#
#   Population Estimate (as of July 1) Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                               2020       2021       2022       2023
# 1                          6,927,904  6,965,740  7,062,217  7,148,304
# 2                             77,327     77,632     79,016     80,343
#
#   Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 20  \
# 0       2024         NaN         NaN         NaN  ...          NaN
# 1  7,227,750         NaN         NaN         NaN  ...          NaN
# 2     81,449         NaN         NaN         NaN  ...          NaN
#
#    Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 26  Unnamed: 27  Unnamed: 28  Unnamed: 29
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
#
# [3 rows x 30 columns]

# %%
TN_pop.columns
# Out:
# Index(['Geographic Area', 'April 1, 2020 Estimates Base',
#        'Population Estimate (as of July 1)', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29'],
#       dtype='object')

# %%
TN_pop=TN_pop[['Geographic Area',
       'Population Estimate (as of July 1)', 'Unnamed: 3', 'Unnamed: 4',
       'Unnamed: 5', 'Unnamed: 6']]

# %%
TN_pop
# Out:
#                   Geographic Area Population Estimate (as of July 1)  \
# 0                             NaN                               2020
# 1                       Tennessee                          6,927,904
# 2     .Anderson County, Tennessee                             77,327
# 3      .Bedford County, Tennessee                             50,396
# 4       .Benton County, Tennessee                             15,853
# ..                            ...                                ...
# 92       .Wayne County, Tennessee                             16,225
# 93     .Weakley County, Tennessee                             32,897
# 94       .White County, Tennessee                             27,446
# 95  .Williamson County, Tennessee                            249,616
# 96      .Wilson County, Tennessee                            148,651
#
#    Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 0        2021       2022       2023       2024
# 1   6,965,740  7,062,217  7,148,304  7,227,750
# 2      77,632     79,016     80,343     81,449
# 3      51,201     52,088     53,274     54,228
# 4      15,836     16,001     16,167     16,173
# ..        ...        ...        ...        ...
# 92     16,334     16,259     16,047     15,974
# 93     32,880     33,032     33,110     33,162
# 94     27,544     28,004     28,697     29,108
# 95    256,155    261,536    265,312    269,136
# 96    152,044    159,029    164,352    169,948
#
# [97 rows x 6 columns]

# %%
TN_pop.columns=['County','Pop_2020','Pop_2021','Pop_2022','Pop_2023','Pop_2024']

# %%
TN_pop=TN_pop.drop(index=[0,1])

# %%
TN_pop
# Out:
#                            County Pop_2020 Pop_2021 Pop_2022 Pop_2023 Pop_2024
# 2     .Anderson County, Tennessee   77,327   77,632   79,016   80,343   81,449
# 3      .Bedford County, Tennessee   50,396   51,201   52,088   53,274   54,228
# 4       .Benton County, Tennessee   15,853   15,836   16,001   16,167   16,173
# 5      .Bledsoe County, Tennessee   14,955   14,839   14,769   15,008   15,591
# 6       .Blount County, Tennessee  135,656  137,624  139,789  141,384  142,211
# ..                            ...      ...      ...      ...      ...      ...
# 92       .Wayne County, Tennessee   16,225   16,334   16,259   16,047   15,974
# 93     .Weakley County, Tennessee   32,897   32,880   33,032   33,110   33,162
# 94       .White County, Tennessee   27,446   27,544   28,004   28,697   29,108
# 95  .Williamson County, Tennessee  249,616  256,155  261,536  265,312  269,136
# 96      .Wilson County, Tennessee  148,651  152,044  159,029  164,352  169,948
#
# [95 rows x 6 columns]

# %%
TN_pop['County']=TN_pop['County'].str[1:]

# %%
TN_pop
# Out:
#                           County Pop_2020 Pop_2021 Pop_2022 Pop_2023 Pop_2024
# 2     Anderson County, Tennessee   77,327   77,632   79,016   80,343   81,449
# 3      Bedford County, Tennessee   50,396   51,201   52,088   53,274   54,228
# 4       Benton County, Tennessee   15,853   15,836   16,001   16,167   16,173
# 5      Bledsoe County, Tennessee   14,955   14,839   14,769   15,008   15,591
# 6       Blount County, Tennessee  135,656  137,624  139,789  141,384  142,211
# ..                           ...      ...      ...      ...      ...      ...
# 92       Wayne County, Tennessee   16,225   16,334   16,259   16,047   15,974
# 93     Weakley County, Tennessee   32,897   32,880   33,032   33,110   33,162
# 94       White County, Tennessee   27,446   27,544   28,004   28,697   29,108
# 95  Williamson County, Tennessee  249,616  256,155  261,536  265,312  269,136
# 96      Wilson County, Tennessee  148,651  152,044  159,029  164,352  169,948
#
# [95 rows x 6 columns]

# %%
TN_pop['County']=TN_pop['County'].str.split(',',expand=True)[0]

# %%
TN_23_population = TN_pop[['County','Pop_2023']]
TN_23_population.head()
# Out:
#             County Pop_2023
# 2  Anderson County   80,343
# 3   Bedford County   53,274
# 4    Benton County   16,167
# 5   Bledsoe County   15,008
# 6    Blount County  141,384

# %%
TN_23_casecounts.head()
# Out:
#                County      State  Case_count_2023
# 2428  Anderson County  Tennessee                0
# 2429   Bedford County  Tennessee                0
# 2430    Benton County  Tennessee                0
# 2431   Bledsoe County  Tennessee                0
# 2432    Blount County  Tennessee                0

# %%
TN_counties_incidence = pd.merge(TN_23_population,TN_23_casecounts,on='County')
TN_counties_incidence.head(3)
# Out:
#             County Pop_2023      State  Case_count_2023
# 0  Anderson County   80,343  Tennessee                0
# 1   Bedford County   53,274  Tennessee                0
# 2    Benton County   16,167  Tennessee                0

# %%
TN_counties_incidence.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   County           95 non-null     object
#  1   Pop_2023         95 non-null     object
#  2   State            95 non-null     object
#  3   Case_count_2023  95 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 3.1+ KB

# %%
TN_counties_incidence['Pop_2023']= TN_counties_incidence['Pop_2023'].str.replace(',','', regex=False).astype(int)

# %%
TN_counties_incidence.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   County           95 non-null     object
#  1   Pop_2023         95 non-null     int64
#  2   State            95 non-null     object
#  3   Case_count_2023  95 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 3.1+ KB

# %%
TN_counties_incidence['incidence_rate']=round((TN_counties_incidence['Case_count_2023']/TN_counties_incidence['Pop_2023'])*100000,2)

# %%
TN_counties_incidence.columns
# Out:
# Index(['County', 'Pop_2023', 'State', 'Case_count_2023', 'incidence_rate'], dtype='object')

# %%
TN_counties_incidence=TN_counties_incidence[['County','State','Pop_2023','Case_count_2023','incidence_rate']]

# %%
TN_counties_incidence=TN_counties_incidence.rename(columns={'incidence_rate':'incidence_rate_per_100k'})

# %%
TN_counties_incidence
# Out:
#                County      State  Pop_2023  Case_count_2023  \
# 0     Anderson County  Tennessee     80343                0
# 1      Bedford County  Tennessee     53274                0
# 2       Benton County  Tennessee     16167                0
# 3      Bledsoe County  Tennessee     15008                0
# 4       Blount County  Tennessee    141384                0
# ..                ...        ...       ...              ...
# 90       Wayne County  Tennessee     16047                0
# 91     Weakley County  Tennessee     33110                0
# 92       White County  Tennessee     28697                0
# 93  Williamson County  Tennessee    265312                3
# 94      Wilson County  Tennessee    164352                0
#
#     incidence_rate_per_100k
# 0                      0.00
# 1                      0.00
# 2                      0.00
# 3                      0.00
# 4                      0.00
# ..                      ...
# 90                     0.00
# 91                     0.00
# 92                     0.00
# 93                     1.13
# 94                     0.00
#
# [95 rows x 5 columns]

# %%
TN_counties_incidence.sort_values(by='incidence_rate_per_100k',ascending=False).head(25)
# Out:
#                County      State  Pop_2023  Case_count_2023  \
# 45     Johnson County  Tennessee     18376                4
# 68     Pickett County  Tennessee      5114                1
# 85      Unicoi County  Tennessee     17812                3
# 33     Hancock County  Tennessee      6963                1
# 28    Grainger County  Tennessee     24697                2
# 17  Cumberland County  Tennessee     64848                4
# 89  Washington County  Tennessee    138628                8
# 86       Union County  Tennessee     20747                1
# 66     Overton County  Tennessee     23358                1
# 9       Carter County  Tennessee     57112                2
# 12   Claiborne County  Tennessee     32738                1
# 6     Campbell County  Tennessee     40225                1
# 81    Sullivan County  Tennessee    162054                3
# 44   Jefferson County  Tennessee     57897                1
# 29      Greene County  Tennessee     72546                1
# 73   Robertson County  Tennessee     76820                1
# 93  Williamson County  Tennessee    265312                3
# 46        Knox County  Tennessee    501576                5
# 82      Sumner County  Tennessee    208423                2
# 62  Montgomery County  Tennessee    240398                1
# 18    Davidson County  Tennessee    719092                3
# 74  Rutherford County  Tennessee    369649                1
# 14       Cocke County  Tennessee     37272                0
# 5      Bradley County  Tennessee    112132                0
# 4       Blount County  Tennessee    141384                0
#
#     incidence_rate_per_100k
# 45                    21.77
# 68                    19.55
# 85                    16.84
# 33                    14.36
# 28                     8.10
# 17                     6.17
# 89                     5.77
# 86                     4.82
# 66                     4.28
# 9                      3.50
# 12                     3.05
# 6                      2.49
# 81                     1.85
# 44                     1.73
# 29                     1.38
# 73                     1.30
# 93                     1.13
# 46                     1.00
# 82                     0.96
# 62                     0.42
# 18                     0.42
# 74                     0.27
# 14                     0.00
# 5                      0.00
# 4                      0.00

# %%
TN_counties_incidence['full_county']=TN_counties_incidence['County']+', '+TN_counties_incidence['State']

# %%
TN_counties_incidence
# Out:
#                County      State  Pop_2023  Case_count_2023  \
# 0     Anderson County  Tennessee     80343                0
# 1      Bedford County  Tennessee     53274                0
# 2       Benton County  Tennessee     16167                0
# 3      Bledsoe County  Tennessee     15008                0
# 4       Blount County  Tennessee    141384                0
# ..                ...        ...       ...              ...
# 90       Wayne County  Tennessee     16047                0
# 91     Weakley County  Tennessee     33110                0
# 92       White County  Tennessee     28697                0
# 93  Williamson County  Tennessee    265312                3
# 94      Wilson County  Tennessee    164352                0
#
#     incidence_rate_per_100k                   full_county
# 0                      0.00    Anderson County, Tennessee
# 1                      0.00     Bedford County, Tennessee
# 2                      0.00      Benton County, Tennessee
# 3                      0.00     Bledsoe County, Tennessee
# 4                      0.00      Blount County, Tennessee
# ..                      ...                           ...
# 90                     0.00       Wayne County, Tennessee
# 91                     0.00     Weakley County, Tennessee
# 92                     0.00       White County, Tennessee
# 93                     1.13  Williamson County, Tennessee
# 94                     0.00      Wilson County, Tennessee
#
# [95 rows x 6 columns]

# %%
TN_counties_incidence.to_csv('../../data/Cleaned Data Python/Cleaned TN County Incidence.csv',index=False)

# %%
top10_tn = TN_counties_incidence.sort_values(by='incidence_rate_per_100k',ascending=False).head(10)

# %%
plt.figure(figsize=(10, 6))
barplot = sns.barplot(
    data=top10_tn,
    y='County',
    x='incidence_rate_per_100k',
    palette='YlGn_r'
)


for container in barplot.containers:
    barplot.bar_label(
        container,
        labels=[f'{v.get_width():,.1f}' for v in container],
        label_type='edge',
        padding=3,
        color='#333333',
        fontsize=10
    )

plt.title('Top 10 Tennessee Counties by Lyme Disease Incidence Rate (2023)', fontsize=14)
plt.xlabel('Incidence Rate per 100,000')
plt.ylabel('County')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\dzapa\AppData\Local\Temp\ipykernel_40948\211733271.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(

# %%
top10_cases = TN_counties_incidence.sort_values(by='Case_count_2023',ascending=False).head(10)

# %%
plt.figure(figsize=(10, 6))
barplot = sns.barplot(
    data=top10_cases,
    y='County',
    x='Case_count_2023',
    palette='YlGn_r'
)

for container in barplot.containers:
    barplot.bar_label(
        container,
        labels=[f'{int(v.get_width()):,}' for v in container],
        label_type='edge',
        padding=3,
        color='#333333',
        fontsize=10
    )

plt.title('Top 10 Tennessee Counties by Lyme Disease Case Count (2023)', fontsize=14)
plt.xlabel('Case Count')
plt.ylabel('County')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\dzapa\AppData\Local\Temp\ipykernel_40948\124747135.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(
