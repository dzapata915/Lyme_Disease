# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
monthly= pd.read_csv('../../data/Case Count by Month 2010-2023.csv')

# %%
monthly
# Out:
#      Year  Cases Onset Month
# 0    2010    551     January
# 1    2010    440    February
# 2    2010    714       March
# 3    2010   1160       April
# 4    2010   2298         May
# ..    ...    ...         ...
# 163  2023    558      August
# 164  2023    229   September
# 165  2023    212     October
# 166  2023    125    November
# 167  2023     65    December
#
# [168 rows x 3 columns]

# %%
monthly['Date']= pd.to_datetime(monthly['Onset Month'] + ' ' + monthly['Year'].astype(str)).dt.to_period('M')
# Out:
# C:\Users\dzapa\AppData\Local\Temp\ipykernel_42780\1290844829.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   monthly['Date']= pd.to_datetime(monthly['Onset Month'] + ' ' + monthly['Year'].astype(str)).dt.to_period('M')

# %%
monthly
# Out:
#      Year  Cases Onset Month     Date
# 0    2010    551     January  2010-01
# 1    2010    440    February  2010-02
# 2    2010    714       March  2010-03
# 3    2010   1160       April  2010-04
# 4    2010   2298         May  2010-05
# ..    ...    ...         ...      ...
# 163  2023    558      August  2023-08
# 164  2023    229   September  2023-09
# 165  2023    212     October  2023-10
# 166  2023    125    November  2023-11
# 167  2023     65    December  2023-12
#
# [168 rows x 4 columns]

# %%
cases_by_month = monthly[['Date','Cases']]
cases_by_month
# Out:
#         Date  Cases
# 0    2010-01    551
# 1    2010-02    440
# 2    2010-03    714
# 3    2010-04   1160
# 4    2010-05   2298
# ..       ...    ...
# 163  2023-08    558
# 164  2023-09    229
# 165  2023-10    212
# 166  2023-11    125
# 167  2023-12     65
#
# [168 rows x 2 columns]

# %%
avg_temps = pd.read_csv('../../data/average US temps by month 2010-2023.csv')

# %%
avg_temps
# Out:
#        Date  Value
# 0    201001  30.67
# 1    201002  31.80
# 2    201003  43.56
# 3    201004  53.24
# 4    201005  59.86
# ..      ...    ...
# 163  202308  74.35
# 164  202309  67.75
# 165  202310  56.03
# 166  202311  44.22
# 167  202312  39.76
#
# [168 rows x 2 columns]

# %%
avg_temps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    168 non-null    int64
#  1   Value   168 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 2.8 KB

# %%
avg_temps['Date']=avg_temps['Date'].astype(str)

# %%
avg_temps['Date']= pd.to_datetime(avg_temps['Date'], format='%Y%m')

# %%
avg_temps['Date']= avg_temps['Date'].dt.to_period('M')

# %%
avg_temps.columns=['Month','Avg_Temp']

# %%
cases_by_month
# Out:
#         Date  Cases
# 0    2010-01    551
# 1    2010-02    440
# 2    2010-03    714
# 3    2010-04   1160
# 4    2010-05   2298
# ..       ...    ...
# 163  2023-08    558
# 164  2023-09    229
# 165  2023-10    212
# 166  2023-11    125
# 167  2023-12     65
#
# [168 rows x 2 columns]

# %%
avg_temps
# Out:
#        Month  Avg_Temp
# 0    2010-01     30.67
# 1    2010-02     31.80
# 2    2010-03     43.56
# 3    2010-04     53.24
# 4    2010-05     59.86
# ..       ...       ...
# 163  2023-08     74.35
# 164  2023-09     67.75
# 165  2023-10     56.03
# 166  2023-11     44.22
# 167  2023-12     39.76
#
# [168 rows x 2 columns]

# %%
cases_vs_temp=pd.merge(avg_temps, cases_by_month, left_on='Month', right_on='Date')

# %%
cases_vs_temp= cases_vs_temp.drop(columns=['Date'])
cases_vs_temp
# Out:
#        Month  Avg_Temp  Cases
# 0    2010-01     30.67    551
# 1    2010-02     31.80    440
# 2    2010-03     43.56    714
# 3    2010-04     53.24   1160
# 4    2010-05     59.86   2298
# ..       ...       ...    ...
# 163  2023-08     74.35    558
# 164  2023-09     67.75    229
# 165  2023-10     56.03    212
# 166  2023-11     44.22    125
# 167  2023-12     39.76     65
#
# [168 rows x 3 columns]

# %% [markdown]
# ## US Average Temp and Total Cases (monthly data)

# %%
cases_vs_temp[['Avg_Temp','Cases']].corr()
# Out:
#           Avg_Temp     Cases
# Avg_Temp  1.000000  0.671611
# Cases     0.671611  1.000000

# %%
plt.figure(figsize=(8, 6))
sns.regplot(data=cases_vs_temp, x='Avg_Temp', y='Cases')
plt.title('Cases vs. Average Temperature')
plt.xlabel('Avg Temp')
plt.ylabel('Cases')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))


sns.regplot(
    data=cases_vs_temp,
    x='Avg_Temp',
    y='Cases',
    scatter_kws={'color': '#8FBC8F', 's': 60, 'edgecolor': 'black', 'alpha': 0.9},  
    line_kws={'color': '#556B2F', 'linewidth': 2},
    ci=None
)


plt.title('Cases vs. Average Temperature', fontsize=14, fontweight='bold')
plt.xlabel('Temperature (°F)', fontsize=12)
plt.ylabel('Cases', fontsize=12)
plt.tight_layout()
plt.show()

# %%
cases_vs_temp = cases_vs_temp.sort_values('Month')
x = cases_vs_temp['Month'].dt.to_timestamp()

fig, ax1 = plt.subplots(figsize=(10, 6))


ax1.set_xlabel('Month')
ax1.set_ylabel('Avg_Temp', color='tab:red')
ax1.plot(x, cases_vs_temp['Avg_Temp'], color='tab:red', marker='o', label='Avg Temp')
ax1.tick_params(axis='y', labelcolor='tab:red')


ax2 = ax1.twinx()
ax2.set_ylabel('Cases', color='tab:blue')
ax2.plot(x, cases_vs_temp['Cases'], color='tab:blue', marker='x', label='Cases')
ax2.tick_params(axis='y', labelcolor='tab:blue')

plt.title('Average Temperature and Cases Over Time')
plt.grid(True)
fig.tight_layout()
plt.show()

# %%
winter_temps = pd.read_csv('../../data/average US temps winter 1996-2023.csv')

# %%
winter_temps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    28 non-null     int64
#  1   Value   28 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 580.0 bytes

# %%
winter_temps
# Out:
#       Date  Value
# 0   199602  32.94
# 1   199702  33.31
# 2   199802  35.90
# 3   199902  36.27
# 4   200002  36.48
# 5   200102  31.26
# 6   200202  35.66
# 7   200302  33.56
# 8   200402  33.07
# 9   200502  35.46
# 10  200602  35.49
# 11  200702  33.44
# 12  200802  32.73
# 13  200902  33.23
# 14  201002  30.70
# 15  201102  31.74
# 16  201202  36.34
# 17  201302  34.31
# 18  201402  31.25
# 19  201502  34.29
# 20  201602  36.78
# 21  201702  35.89
# 22  201802  33.99
# 23  201902  33.30
# 24  202002  36.04
# 25  202102  33.64
# 26  202202  34.72
# 27  202302  34.85

# %%
winter_temps['Date'] = winter_temps['Date'].astype(str)

# %%
winter_temps['Winter_Year'] = winter_temps['Date'].str[:4].astype(int)

# %%
winter_temps['Winter_Year'] = pd.PeriodIndex(winter_temps['Winter_Year'], freq='Y')

# %%
winter_temps= winter_temps[['Winter_Year','Value']]

# %%
winter_temps
# Out:
#    Winter_Year  Value
# 0         1996  32.94
# 1         1997  33.31
# 2         1998  35.90
# 3         1999  36.27
# 4         2000  36.48
# 5         2001  31.26
# 6         2002  35.66
# 7         2003  33.56
# 8         2004  33.07
# 9         2005  35.46
# 10        2006  35.49
# 11        2007  33.44
# 12        2008  32.73
# 13        2009  33.23
# 14        2010  30.70
# 15        2011  31.74
# 16        2012  36.34
# 17        2013  34.31
# 18        2014  31.25
# 19        2015  34.29
# 20        2016  36.78
# 21        2017  35.89
# 22        2018  33.99
# 23        2019  33.30
# 24        2020  36.04
# 25        2021  33.64
# 26        2022  34.72
# 27        2023  34.85

# %%
winter_temps.columns=['Winter_Year','Avg_Temp']

# %%
winter_temps
# Out:
#    Winter_Year  Avg_Temp
# 0         1996     32.94
# 1         1997     33.31
# 2         1998     35.90
# 3         1999     36.27
# 4         2000     36.48
# 5         2001     31.26
# 6         2002     35.66
# 7         2003     33.56
# 8         2004     33.07
# 9         2005     35.46
# 10        2006     35.49
# 11        2007     33.44
# 12        2008     32.73
# 13        2009     33.23
# 14        2010     30.70
# 15        2011     31.74
# 16        2012     36.34
# 17        2013     34.31
# 18        2014     31.25
# 19        2015     34.29
# 20        2016     36.78
# 21        2017     35.89
# 22        2018     33.99
# 23        2019     33.30
# 24        2020     36.04
# 25        2021     33.64
# 26        2022     34.72
# 27        2023     34.85

# %%
US_casecounts= pd.read_csv('../../data/Overall US Case Count by Year 1996-2023.csv')

# %%
US_casecounts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    28 non-null     int64
#  1   Cases   28 non-null     int64
# dtypes: int64(2)
# memory usage: 580.0 bytes

# %%
US_casecounts['Year'] = pd.PeriodIndex(US_casecounts['Year'], freq='Y')

# %%
US_casecounts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    28 non-null     period[Y-DEC]
#  1   Cases   28 non-null     int64
# dtypes: int64(1), period[Y-DEC](1)
# memory usage: 580.0 bytes

# %%
US_casecounts.head(1)
# Out:
#    Year  Cases
# 0  1996  16455

# %%
winter_case_counts = pd.merge(winter_temps, US_casecounts, left_on='Winter_Year', right_on='Year')

# %%
winter_case_counts.head(2)
# Out:
#   Winter_Year  Avg_Temp  Year  Cases
# 0        1996     32.94  1996  16455
# 1        1997     33.31  1997  12801

# %%
winter_case_counts= winter_case_counts.drop(columns='Year')

# %%
winter_case_counts.head()
# Out:
#   Winter_Year  Avg_Temp  Cases
# 0        1996     32.94  16455
# 1        1997     33.31  12801
# 2        1998     35.90  16801
# 3        1999     36.27  16273
# 4        2000     36.48  17730

# %% [markdown]
# ## US Average Winter Temps and Total Cases

# %%
winter_case_counts[['Avg_Temp','Cases']].corr()
# Out:
#           Avg_Temp     Cases
# Avg_Temp  1.000000  0.025675
# Cases     0.025675  1.000000

# %%
plt.figure(figsize=(8, 6))
sns.regplot(data=winter_case_counts, x='Avg_Temp', y='Cases')
plt.title('Winter Average Temperature vs. Cases')
plt.xlabel('Average Winter Temp')
plt.ylabel('Reported Cases')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
x = winter_case_counts['Winter_Year'].dt.to_timestamp()

fig, ax1 = plt.subplots(figsize=(10, 6))


ax1.set_xlabel('Winter Year')
ax1.set_ylabel('Avg Temp', color='tab:blue')
ax1.plot(x, winter_case_counts['Avg_Temp'], marker='o', color='tab:blue', label='Avg Temp')
ax1.tick_params(axis='y', labelcolor='tab:blue')


ax2 = ax1.twinx()
ax2.set_ylabel('Cases', color='tab:red')
ax2.plot(x, winter_case_counts['Cases'], marker='x', color='tab:red', label='Cases')
ax2.tick_params(axis='y', labelcolor='tab:red')

plt.title('Winter Temperatures and Case Counts Over Time')
plt.grid(True)
fig.tight_layout()
plt.show()

# %%
summer_temps = pd.read_csv('../../data/average US temps summer 1996-2023.csv')

# %%
summer_temps.head(1)
# Out:
#      Date  Value
# 0  199608  69.21

# %%
summer_temps['Date'] = summer_temps['Date'].astype(str)

# %%
summer_temps['Summer_Year'] = summer_temps['Date'].str[:4].astype(int)

# %%
summer_temps['Summer_Year'] = pd.PeriodIndex(summer_temps['Summer_Year'], freq='Y')

# %%
summer_temps = summer_temps[['Summer_Year','Value']]

# %%
summer_temps.columns=['Summer_Year','Avg_Temp']

# %%
summer_temps.head(1)
# Out:
#   Summer_Year  Avg_Temp
# 0        1996     69.21

# %%
summer_case_counts = pd.merge(summer_temps, US_casecounts, left_on='Summer_Year', right_on='Year')

# %%
summer_case_counts=summer_case_counts.drop(columns='Year')

# %%
summer_case_counts.head(3)
# Out:
#   Summer_Year  Avg_Temp  Cases
# 0        1996     69.21  16455
# 1        1997     68.14  12801
# 2        1998     70.00  16801

# %% [markdown]
# ## US Average Summer Temps and Total Cases

# %%
summer_case_counts[['Avg_Temp','Cases']].corr()
# Out:
#           Avg_Temp     Cases
# Avg_Temp  1.000000  0.261888
# Cases     0.261888  1.000000

# %%
plt.figure(figsize=(8, 6))
sns.regplot(data=summer_case_counts, x='Avg_Temp', y='Cases')
plt.title('Summer Average Temperature vs. Cases')
plt.xlabel('Average Summer Temp')
plt.ylabel('Reported Cases')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
regional_cases = pd.read_csv('../../data/regional case counts 2010-2023.csv')

# %%
Northeast = regional_cases.loc[(regional_cases['Region']=='New England') | (regional_cases['Region']=='Middle Atlantic')]

# %%
Northeast= Northeast.reset_index(drop=True)

# %%
Northeast = Northeast.groupby('Year')['Cases'].sum().reset_index()

# %%
Northeast.plot(kind='line',x='Year', y='Cases')
# Out:
# <Axes: xlabel='Year'>

# %%
Northeast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    14 non-null     int64
#  1   Cases   14 non-null     int64
# dtypes: int64(2)
# memory usage: 356.0 bytes

# %%
NE_winter = pd.read_csv('../../data/Northeast winter temps.csv')

# %%
NE_winter
# Out:
#       Date  Value
# 0   201002   25.5
# 1   201102   23.1
# 2   201202   30.0
# 3   201302   27.6
# 4   201402   22.1
# 5   201502   20.8
# 6   201602   30.7
# 7   201702   29.5
# 8   201802   25.3
# 9   201902   25.6
# 10  202002   28.9
# 11  202102   27.1
# 12  202202   26.1
# 13  202302   30.7

# %%
NE_winter['Date'] = NE_winter['Date'].astype(str)

# %%
NE_winter['Date'] = NE_winter['Date'].str[:4].astype(int)

# %%
NE_winter.columns=['Year','Avg_Temp']

# %%
NE_winter.plot(kind='line',x='Year', y='Avg_Temp')
# Out:
# <Axes: xlabel='Year'>

# %%
NE_winter
# Out:
#     Year  Avg_Temp
# 0   2010      25.5
# 1   2011      23.1
# 2   2012      30.0
# 3   2013      27.6
# 4   2014      22.1
# 5   2015      20.8
# 6   2016      30.7
# 7   2017      29.5
# 8   2018      25.3
# 9   2019      25.6
# 10  2020      28.9
# 11  2021      27.1
# 12  2022      26.1
# 13  2023      30.7

# %%
plt.figure(figsize=(10, 6))

sns.regplot(
    data=NE_winter,
    x='Year',
    y='Avg_Temp',
    scatter_kws={'color': 'blue', 's': 80},
    line_kws={'color': 'red', 'linewidth': 2, 'label': 'Trend Line'},
    ci=None  
)


plt.title('Northeast: Winter Average Temperature Over Time', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Average Winter Temperature', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))


sns.regplot(
    data=NE_winter,
    x='Year',
    y='Avg_Temp',
    scatter_kws={
        'color': '#8FBC8F',    
        's': 80,
        'edgecolor': 'black',
        'alpha': 0.9
    },
    line_kws={
        'color': '#556B2F',    
        'linewidth': 2,
        'label': 'Trend Line'
    },
    ci=None
)


plt.title('Northeast: Average Winter Temperature', fontsize=14, fontweight='bold')
plt.xlabel('Year', fontsize=12)
plt.ylabel('Temperature (°F)', fontsize=12)


plt.legend()
plt.tight_layout()
plt.show()

# %%
Northeast.head(5)
# Out:
#    Year  Cases
# 0  2010  19900
# 1  2011  22716
# 2  2012  22702
# 3  2013  27031
# 4  2014  25801

# %%
NE_case_temp = pd.merge(NE_winter,Northeast,on='Year')

# %%
NE_case_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      14 non-null     int64
#  1   Avg_Temp  14 non-null     float64
#  2   Cases     14 non-null     int64
# dtypes: float64(1), int64(2)
# memory usage: 468.0 bytes

# %% [markdown]
# ## Northeast Region Average Winter Temp and Cases

# %%
NE_case_temp[['Avg_Temp','Cases']].corr()
# Out:
#           Avg_Temp     Cases
# Avg_Temp  1.000000  0.225021
# Cases     0.225021  1.000000

# %%
plt.figure(figsize=(8, 6))
sns.regplot(data=NE_case_temp, x='Avg_Temp', y='Cases')
plt.title('Northeast Winter Average Temperature vs. Cases')
plt.xlabel('Average Winter Temp')
plt.ylabel('Reported Cases')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))

sns.regplot(
    data=NE_case_temp,
    x='Avg_Temp',
    y='Cases',
    scatter_kws={
        'color': '#8FBC8F',    
        's': 80,
        'edgecolor': 'black',
        'alpha': 0.9
    },
    line_kws={
        'color': '#556B2F',    
        'linewidth': 2
    },
    ci=None
)


plt.title('Northeast: Cases vs. Average Winter Temperature', fontsize=14, fontweight='bold')
plt.xlabel('Temperature (°F)', fontsize=12)
plt.ylabel('Cases', fontsize=12)



plt.tight_layout()
plt.ylim(bottom=0)
plt.show()

# %%
ohio_winter = pd.read_csv('../../data/Ohio winter temps.csv')

# %%
ohio_winter
# Out:
#       Date  Value
# 0   200802   30.2
# 1   200902   27.7
# 2   201002   27.1
# 3   201102   26.3
# 4   201202   34.7
# 5   201302   32.5
# 6   201402   25.1
# 7   201502   25.7
# 8   201602   34.8
# 9   201702   35.4
# 10  201802   30.3
# 11  201902   31.8
# 12  202002   34.6
# 13  202102   29.9
# 14  202202   31.6
# 15  202302   36.0

# %%
ohio_winter['Date'] = ohio_winter['Date'].astype(str)

# %%
ohio_winter['Date'] = ohio_winter['Date'].str[:4].astype(int)

# %%
ohio_winter.columns=['Year','Avg_Temp']

# %%
ohio_winter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      16 non-null     int64
#  1   Avg_Temp  16 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 388.0 bytes

# %%
plt.figure(figsize=(10, 6))

sns.regplot(
    data=ohio_winter,
    x='Year',
    y='Avg_Temp',
    scatter_kws={'color': 'blue', 's': 80},
    line_kws={'color': 'red', 'linewidth': 2, 'label': 'Trend Line'},
    ci=None  
)


plt.title('Ohio: Winter Average Temperature Over Time', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Average Winter Temperature (°F)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.regplot(
    data=ohio_winter,
    x='Year',
    y='Avg_Temp',
    scatter_kws={
        'color': '#8FBC8F',
        's': 80,
        'edgecolor': 'black',
        'alpha': 0.9
    },
    line_kws={
        'color': '#556B2F',
        'linewidth': 2,
        'label': 'Trend Line'
    },
    ci=None
)

plt.title('Ohio: Average Winter Temperature', fontsize=14, fontweight='bold')
plt.xlabel('Year', fontsize=12)
plt.ylabel('Temperature (°F)', fontsize=12)
plt.legend()
plt.tight_layout()
plt.show()

# %%
state_cases= pd.read_csv('../../data/Case Count by State 2008-2023.csv')

# %%
Ohio =state_cases.loc[state_cases['State']=='Ohio']
Ohio
# Out:
#    State 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020  \
# 34  Ohio   45   58   44   53   67   93  119  154  160  270  293  467  409
#
#    2021 2022   2023
# 34  590  553  1,307

# %%
Ohio = pd.melt(Ohio, id_vars=['State'], var_name='Year', value_name='Value')

# %%
Ohio=Ohio[['Year','Value']]

# %%
Ohio.columns=['Year','Case_Count']

# %%
Ohio
# Out:
#     Year Case_Count
# 0   2008         45
# 1   2009         58
# 2   2010         44
# 3   2011         53
# 4   2012         67
# 5   2013         93
# 6   2014        119
# 7   2015        154
# 8   2016        160
# 9   2017        270
# 10  2018        293
# 11  2019        467
# 12  2020        409
# 13  2021        590
# 14  2022        553
# 15  2023      1,307

# %%
Ohio['Case_Count'] = Ohio['Case_Count'].replace(',', '', regex=True).astype(int)

# %%
Ohio['Year']=Ohio['Year'].astype(int)

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=Ohio, x='Year', y='Case_Count', marker='o', color='#556B2F')
plt.title('Ohio Lyme Disease Cases (2008–2023)', fontsize=14)
plt.xlabel('Year')
plt.ylabel('Reported Cases')
plt.tight_layout()
plt.show()

# %%
Ohio_case_wintertemp= pd.merge(ohio_winter, Ohio,on='Year')

# %%
Ohio_case_wintertemp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        16 non-null     int64
#  1   Avg_Temp    16 non-null     float64
#  2   Case_Count  16 non-null     int64
# dtypes: float64(1), int64(2)
# memory usage: 516.0 bytes

# %%
Ohio_case_wintertemp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        16 non-null     int64
#  1   Avg_Temp    16 non-null     float64
#  2   Case_Count  16 non-null     int64
# dtypes: float64(1), int64(2)
# memory usage: 516.0 bytes

# %% [markdown]
# ## Ohio Average Winter Temps vs Case Count

# %%
Ohio_case_wintertemp[['Avg_Temp','Case_Count']].corr()
# Out:
#             Avg_Temp  Case_Count
# Avg_Temp    1.000000    0.472377
# Case_Count  0.472377    1.000000

# %%
plt.figure(figsize=(8, 6))
sns.regplot(
    data=Ohio_case_wintertemp,
    x='Avg_Temp',
    y='Case_Count',
    scatter_kws={'s': 100, 'color': 'blue', 'alpha': 0.7}, 
    line_kws={'color': 'red', 'linewidth': 2}, 
    ci=None,  
    robust=True 
)


plt.ylim(bottom=0)


plt.title('Ohio Winter Average Temperature vs. Reported Cases', fontsize=16)
plt.xlabel('Average Winter Temperature (°C)', fontsize=12)
plt.ylabel('Reported Cases', fontsize=12)


plt.grid(True, linestyle='--', alpha=0.7) 
plt.tight_layout()

# %%
plt.figure(figsize=(10, 6))


scatter = plt.scatter(
    Ohio_case_wintertemp['Avg_Temp'],
    Ohio_case_wintertemp['Case_Count'],
    c=Ohio_case_wintertemp['Year'],
    cmap='viridis',
    s=100,
    alpha=0.9,
    edgecolor='black',
    label='Yearly Data Points'
)


sns.regplot(
    data=Ohio_case_wintertemp,
    x='Avg_Temp',
    y='Case_Count',
    scatter=False,  
    color='red',
    line_kws={'linewidth': 2, 'label': 'Trend Line'},
    ci=None  
)


cbar = plt.colorbar(scatter)
cbar.set_label('Year')


plt.title('Ohio: Winter Avg Temp vs Case Count', fontsize=14)
plt.xlabel('Average Winter Temperature (°F)', fontsize=12)
plt.ylabel('Case Count', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

scatter = plt.scatter(
    Ohio_case_wintertemp['Avg_Temp'],
    Ohio_case_wintertemp['Case_Count'],
    c=Ohio_case_wintertemp['Year'],
    cmap='YlGn',
    s=100,
    alpha=0.9,
    edgecolor='black',
    label='Yearly Data Points'
)

sns.regplot(
    data=Ohio_case_wintertemp,
    x='Avg_Temp',
    y='Case_Count',
    scatter=False,
    color='#556B2F',
    line_kws={'linewidth': 2, 'label': 'Trend Line'},
    ci=None
)

cbar = plt.colorbar(scatter)
cbar.set_label('Year')

plt.title('Ohio: Cases vs Average Winter Temperature', fontsize=14, fontweight='bold')
plt.xlabel('Temperature (°F)', fontsize=12)
plt.ylabel('Cases', fontsize=12)
plt.ylim(bottom=0)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## West Virginia

# %%
WV_winter = pd.read_csv('../../data/West Virginia winter temps.csv')

# %%
WV_winter
# Out:
#       Date  Value
# 0   200802   34.3
# 1   200902   32.1
# 2   201002   29.1
# 3   201102   29.7
# 4   201202   37.0
# 5   201302   35.1
# 6   201402   30.1
# 7   201502   29.9
# 8   201602   36.3
# 9   201702   38.4
# 10  201802   33.9
# 11  201902   35.7
# 12  202002   37.9
# 13  202102   32.8
# 14  202202   35.1
# 15  202302   38.3

# %%
WV_winter['Date'] = WV_winter['Date'].astype(str)

# %%
WV_winter['Date'] = WV_winter['Date'].str[:4].astype(int)

# %%
WV_winter.columns=['Year','Avg_Temp']
WV_winter
# Out:
#     Year  Avg_Temp
# 0   2008      34.3
# 1   2009      32.1
# 2   2010      29.1
# 3   2011      29.7
# 4   2012      37.0
# 5   2013      35.1
# 6   2014      30.1
# 7   2015      29.9
# 8   2016      36.3
# 9   2017      38.4
# 10  2018      33.9
# 11  2019      35.7
# 12  2020      37.9
# 13  2021      32.8
# 14  2022      35.1
# 15  2023      38.3

# %%
plt.figure(figsize=(10, 6))

sns.regplot(
    data=WV_winter,
    x='Year',
    y='Avg_Temp',
    scatter_kws={'color': 'blue', 's': 80},
    line_kws={'color': 'red', 'linewidth': 2, 'label': 'Trend Line'},
    ci=None  
)


plt.title('West Virginia: Winter Average Temperature Over Time', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Average Winter Temperature (°F)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.regplot(
    data=WV_winter,
    x='Year',
    y='Avg_Temp',
    scatter_kws={
        'color': '#8FBC8F',
        's': 80,
        'edgecolor': 'black',
        'alpha': 0.9
    },
    line_kws={
        'color': '#556B2F',
        'linewidth': 2,
        'label': 'Trend Line'
    },
    ci=None
)

plt.title('West Virginia: Average Winter Temperature', fontsize=14, fontweight='bold')
plt.xlabel('Year', fontsize=12)
plt.ylabel('Temperature (°F)', fontsize=12)
plt.legend()
plt.tight_layout()
plt.show()

# %%
state_cases
# Out:
#                     State    2008    2009    2010    2011    2012    2013  \
# 0                 Alabama       9       3       2      24      25      24
# 1                  Alaska       6       7       7      11      10      14
# 2                 Arizona       8       7       2      15      13      32
# 3                Arkansas       0       0       0       0       0       0
# 4              California      74     117     129      92      70     112
# 5                Colorado       3       1       3       0       0       0
# 6            Connecticut†   3,896   4,156   3,068   3,039   2,657   2,925
# 7               Delaware†     772     984     656     873     669     509
# 8   District of Columbia†      74      61      42       0       0      35
# 9                 Florida      88     110      84     115     118     138
# 10                Georgia      35      40      10      32      31       8
# 11                  Idaho       9      16       9       4       5      19
# ...

# %%
state_cases['State']=state_cases['State'].str.replace('†','',regex=False)

# %%
WV_cases = state_cases.loc[state_cases['State']=='West Virginia']

# %%
WV_cases = pd.melt(WV_cases, id_vars=['State'], var_name='Year', value_name='Value')

# %%
WV_cases=WV_cases[['Year','Value']]

# %%
WV_cases.columns=['Year','Case_Count']

# %%
WV_cases['Year']=WV_cases['Year'].astype(int)

# %%
WV_cases
# Out:
#     Year Case_Count
# 0   2008        135
# 1   2009        201
# 2   2010        145
# 3   2011        118
# 4   2012         97
# 5   2013        143
# 6   2014        136
# 7   2015        289
# 8   2016        368
# 9   2017        648
# 10  2018        671
# 11  2019        885
# 12  2020      1,065
# 13  2021      1,792
# 14  2022       2470
# 15  2023      3,242

# %%
WV_case_wintertemp= pd.merge(WV_winter, WV_cases,on='Year')

# %%
WV_case_wintertemp['Case_Count'] = pd.to_numeric(WV_case_wintertemp['Case_Count'].str.replace(',', ''), errors='coerce')

# %%
WV_case_wintertemp
# Out:
#     Year  Avg_Temp  Case_Count
# 0   2008      34.3         135
# 1   2009      32.1         201
# 2   2010      29.1         145
# 3   2011      29.7         118
# 4   2012      37.0          97
# 5   2013      35.1         143
# 6   2014      30.1         136
# 7   2015      29.9         289
# 8   2016      36.3         368
# 9   2017      38.4         648
# 10  2018      33.9         671
# 11  2019      35.7         885
# 12  2020      37.9        1065
# 13  2021      32.8        1792
# 14  2022      35.1        2470
# 15  2023      38.3        3242

# %% [markdown]
# ## West Virginia Winter Temps vs Case Count

# %%
WV_case_wintertemp[['Avg_Temp','Case_Count']].corr()
# Out:
#             Avg_Temp  Case_Count
# Avg_Temp    1.000000    0.435974
# Case_Count  0.435974    1.000000

# %%
plt.figure(figsize=(8, 6))
sns.regplot(
    data=WV_case_wintertemp,
    x='Avg_Temp',
    y='Case_Count',
    scatter_kws={'s': 100, 'color': 'blue', 'alpha': 0.7}, 
    line_kws={'color': 'red', 'linewidth': 2}, 
    ci=None,  
    robust=True 
)


plt.ylim(bottom=0)


plt.title('West Virginia Winter Average Temperature vs. Reported Cases', fontsize=16)
plt.xlabel('Average Winter Temperature', fontsize=12)
plt.ylabel('Reported Cases', fontsize=12)


plt.grid(True, linestyle='--', alpha=0.7) 
plt.tight_layout()

# %%
plt.figure(figsize=(10, 6))


scatter = plt.scatter(
    WV_case_wintertemp['Avg_Temp'],
    WV_case_wintertemp['Case_Count'],
    c=WV_case_wintertemp['Year'],
    cmap='viridis',
    s=100,
    alpha=0.9,
    edgecolor='black',
    label='Yearly Data Points'
)


sns.regplot(
    data=WV_case_wintertemp,
    x='Avg_Temp',
    y='Case_Count',
    scatter=False,  
    color='red',
    line_kws={'linewidth': 2, 'label': 'Trend Line'},
    ci=None  
)


cbar = plt.colorbar(scatter)
cbar.set_label('Year')


plt.title('West Virginia: Winter Avg Temp vs Case Count', fontsize=14)
plt.xlabel('Average Winter Temperature (°F)', fontsize=12)
plt.ylabel('Case Count', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

scatter = plt.scatter(
    WV_case_wintertemp['Avg_Temp'],
    WV_case_wintertemp['Case_Count'],
    c=WV_case_wintertemp['Year'],
    cmap='YlGn',
    s=100,
    alpha=0.9,
    edgecolor='black',
    label='Yearly Data Points'
)

sns.regplot(
    data=WV_case_wintertemp,
    x='Avg_Temp',
    y='Case_Count',
    scatter=False,
    color='#556B2F',
    line_kws={'linewidth': 2, 'label': 'Trend Line'},
    ci=None
)

cbar = plt.colorbar(scatter)
cbar.set_label('Year')

plt.title('West Virginia: Cases vs Average Winter Temperature', fontsize=14, fontweight='bold')
plt.xlabel('Temperature (°F)', fontsize=12)
plt.ylabel('Cases', fontsize=12)
plt.ylim(bottom=0)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Kentucky

# %%
Kentucky_winter = pd.read_csv('../../data/Kentucky winter temps.csv')
Kentucky_winter
# Out:
#       Date  Value
# 0   200802   37.2
# 1   200902   35.3
# 2   201002   32.0
# 3   201102   32.8
# 4   201202   40.3
# 5   201302   38.8
# 6   201402   32.5
# 7   201502   32.7
# 8   201602   39.7
# 9   201702   41.4
# 10  201802   36.8
# 11  201902   39.3
# 12  202002   40.7
# 13  202102   35.1
# 14  202202   39.1
# 15  202302   42.0

# %%
Kentucky_winter['Date'] = Kentucky_winter['Date'].astype(str)

# %%
Kentucky_winter['Date'] = Kentucky_winter['Date'].str[:4].astype(int)

# %%
Kentucky_winter.columns=['Year','Avg_Temp']

# %%
Kentucky_winter
# Out:
#     Year  Avg_Temp
# 0   2008      37.2
# 1   2009      35.3
# 2   2010      32.0
# 3   2011      32.8
# 4   2012      40.3
# 5   2013      38.8
# 6   2014      32.5
# 7   2015      32.7
# 8   2016      39.7
# 9   2017      41.4
# 10  2018      36.8
# 11  2019      39.3
# 12  2020      40.7
# 13  2021      35.1
# 14  2022      39.1
# 15  2023      42.0

# %%
plt.figure(figsize=(10, 6))

sns.regplot(
    data=Kentucky_winter,
    x='Year',
    y='Avg_Temp',
    scatter_kws={'color': 'blue', 's': 80},
    line_kws={'color': 'red', 'linewidth': 2, 'label': 'Trend Line'},
    ci=None  
)


plt.title('Kentucky: Winter Average Temperature Over Time', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Average Winter Temperature (°F)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.regplot(
    data=Kentucky_winter,
    x='Year',
    y='Avg_Temp',
    scatter_kws={
        'color': '#8FBC8F',
        's': 80,
        'edgecolor': 'black',
        'alpha': 0.9
    },
    line_kws={
        'color': '#556B2F',
        'linewidth': 2,
        'label': 'Trend Line'
    },
    ci=None
)

plt.title('Kentucky: Winter Average Temperature Over Time', fontsize=14, fontweight='bold')
plt.xlabel('Year', fontsize=12)
plt.ylabel('Average Winter Temperature (°F)', fontsize=12)
plt.legend()
plt.tight_layout()
plt.show()

# %%
Kentucky_cases = state_cases.loc[state_cases['State']=='Kentucky']

# %%
Kentucky_cases = pd.melt(Kentucky_cases, id_vars=['State'], var_name='Year', value_name='Value')

# %%
Kentucky_cases=Kentucky_cases[['Year','Value']]

# %%
Kentucky_cases.columns=['Year','Case_Count']

# %%
Kentucky_cases['Year']=Kentucky_cases['Year'].astype(int)

# %%
Kentucky_cases
# Out:
#     Year Case_Count
# 0   2008          5
# 1   2009          1
# 2   2010          5
# 3   2011          3
# 4   2012         14
# 5   2013         40
# 6   2014         44
# 7   2015         49
# 8   2016         33
# 9   2017         20
# 10  2018         22
# 11  2019         22
# 12  2020         32
# 13  2021         41
# 14  2022         72
# 15  2023        120

# %%
Kentucky_case_wintertemp= pd.merge(Kentucky_winter, Kentucky_cases,on='Year')

# %%
Kentucky_case_wintertemp['Case_Count'] = pd.to_numeric(Kentucky_case_wintertemp['Case_Count'].str.replace(',', ''), errors='coerce')

# %% [markdown]
# ## Kentucky Avg Winter Temp vs Case Count

# %%
Kentucky_case_wintertemp
# Out:
#     Year  Avg_Temp  Case_Count
# 0   2008      37.2           5
# 1   2009      35.3           1
# 2   2010      32.0           5
# 3   2011      32.8           3
# 4   2012      40.3          14
# 5   2013      38.8          40
# 6   2014      32.5          44
# 7   2015      32.7          49
# 8   2016      39.7          33
# 9   2017      41.4          20
# 10  2018      36.8          22
# 11  2019      39.3          22
# 12  2020      40.7          32
# 13  2021      35.1          41
# 14  2022      39.1          72
# 15  2023      42.0         120

# %%
Kentucky_case_wintertemp[['Avg_Temp','Case_Count']].corr()
# Out:
#             Avg_Temp  Case_Count
# Avg_Temp     1.00000     0.36185
# Case_Count   0.36185     1.00000

# %%
plt.figure(figsize=(10, 6))


scatter = plt.scatter(
    Kentucky_case_wintertemp['Avg_Temp'],
    Kentucky_case_wintertemp['Case_Count'],
    c=Kentucky_case_wintertemp['Year'],
    cmap='viridis',
    s=100,
    alpha=0.9,
    edgecolor='black',
    label='Yearly Data Points'
)


sns.regplot(
    data=Kentucky_case_wintertemp,
    x='Avg_Temp',
    y='Case_Count',
    scatter=False,  
    color='red',
    line_kws={'linewidth': 2, 'label': 'Trend Line'},
    ci=None  
)


cbar = plt.colorbar(scatter)
cbar.set_label('Year')


plt.title('Kentucky: Winter Avg Temp vs Case Count', fontsize=14)
plt.xlabel('Average Winter Temperature (°F)', fontsize=12)
plt.ylabel('Case Count', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))


scatter = plt.scatter(
    Kentucky_case_wintertemp['Avg_Temp'],
    Kentucky_case_wintertemp['Case_Count'],
    c=Kentucky_case_wintertemp['Year'],
    cmap='YlGn',  
    s=100,
    alpha=0.9,
    edgecolor='black',
    label='Yearly Data Points'
)


sns.regplot(
    data=Kentucky_case_wintertemp,
    x='Avg_Temp',
    y='Case_Count',
    scatter=False,
    color='#556B2F', 
    line_kws={'linewidth': 2, 'label': 'Trend Line'},
    ci=None
)


cbar = plt.colorbar(scatter)
cbar.set_label('Year')


plt.title('Kentucky: Winter Avg Temp vs Case Count', fontsize=14, fontweight='bold')
plt.xlabel('Average Winter Temperature (°F)', fontsize=12)
plt.ylabel('Case Count', fontsize=12)
plt.legend()
plt.tight_layout()
plt.show()

# %%
winter_temps
# Out:
#    Winter_Year  Avg_Temp
# 0         1996     32.94
# 1         1997     33.31
# 2         1998     35.90
# 3         1999     36.27
# 4         2000     36.48
# 5         2001     31.26
# 6         2002     35.66
# 7         2003     33.56
# 8         2004     33.07
# 9         2005     35.46
# 10        2006     35.49
# 11        2007     33.44
# 12        2008     32.73
# 13        2009     33.23
# 14        2010     30.70
# 15        2011     31.74
# 16        2012     36.34
# 17        2013     34.31
# 18        2014     31.25
# 19        2015     34.29
# 20        2016     36.78
# 21        2017     35.89
# 22        2018     33.99
# 23        2019     33.30
# 24        2020     36.04
# 25        2021     33.64
# 26        2022     34.72
# 27        2023     34.85

# %%
US_winteravg = pd.read_csv('../../data/average US temps winter 1996-2023.csv')

# %%
US_winteravg
# Out:
#       Date  Value
# 0   199602  32.94
# 1   199702  33.31
# 2   199802  35.90
# 3   199902  36.27
# 4   200002  36.48
# 5   200102  31.26
# 6   200202  35.66
# 7   200302  33.56
# 8   200402  33.07
# 9   200502  35.46
# 10  200602  35.49
# 11  200702  33.44
# 12  200802  32.73
# 13  200902  33.23
# 14  201002  30.70
# 15  201102  31.74
# 16  201202  36.34
# 17  201302  34.31
# 18  201402  31.25
# 19  201502  34.29
# 20  201602  36.78
# 21  201702  35.89
# 22  201802  33.99
# 23  201902  33.30
# 24  202002  36.04
# 25  202102  33.64
# 26  202202  34.72
# 27  202302  34.85

# %%
US_winteravg['Date'] = US_winteravg['Date'].astype(str)

# %%
US_winteravg['Date'] = US_winteravg['Date'].str[:4].astype(int)

# %%
US_winteravg.columns=['Year','Avg_Temp']

# %%
US_winteravg.head()
# Out:
#    Year  Avg_Temp
# 0  1996     32.94
# 1  1997     33.31
# 2  1998     35.90
# 3  1999     36.27
# 4  2000     36.48

# %%
plt.figure(figsize=(10, 6))

sns.regplot(
    data=US_winteravg,
    x='Year',
    y='Avg_Temp',
    scatter_kws={'color': 'blue', 's': 80},
    line_kws={'color': 'red', 'linewidth': 2, 'label': 'Trend Line'},
    ci=None  
)


plt.title('United States Overall: Winter Average Temperature Over Time', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Average Winter Temperature', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.regplot(
    data=US_winteravg,
    x='Year',
    y='Avg_Temp',
    scatter_kws={
        'color': '#8FBC8F',
        's': 80,
        'edgecolor': 'black',
        'alpha': 0.9
    },
    line_kws={
        'color': '#556B2F',
        'linewidth': 2,
        'label': 'Trend Line'
    },
    ci=None
)

plt.title('US: Average Winter Temperature', fontsize=14, fontweight='bold')
plt.xlabel('Year', fontsize=12)
plt.ylabel('Temperature (°F)', fontsize=12)
plt.legend()
plt.tight_layout()
plt.show()
